# %% [markdown]
# <h2><center>Examen 2025 - 2026<br><br>
# SLEBF500 - Programmation Python Avancée et POO<br><br>
#     <span style='background : salmon' > SUJET D'EXAMEN </span>
# </center></h2>
#
# **Session 2**
# **Durée : 2 heures**
#
# Ce jupyter notebook est à compléter sur les ordinateurs de la salle d'examen.
# Tous les supports de cours et TP sont autorisés. Les documents de cours et TD sont à télécharger depuis l'espace moodle.
#
# **CONSIGNES :**
# * **Logiciel VS Code prohibé.**
# * **PAS DE CHATGPT, GEMINI, COPILOT, CLAUDE, ET AUTRES LLM !**
# * Une fois terminé, soumettez le fichier sur Moodle sous la forme : `NOM_Examen_Python_S2.ipynb`.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("Modules chargés.")

# %% [markdown]
# # Exercice 1 - Manipulation de données avec Pandas (7 points)
#
# **Q1.1 :** Créez un DataFrame à partir du dictionnaire suivant et affichez les 5 premières lignes.

# %%
data = {
    'Produit': ['Ordinateur', 'Clavier', 'Souris', 'Écran', 'Ordinateur', 'Souris', 'Écran'],
    'Ventes': [1200, 150, 80, 450, 1300, 90, 400],
    'Date': ['2023-01-10', '2023-01-12', '2023-01-15', '2023-01-15', '2023-02-01', '2023-02-05', '2023-02-10']
}
# Votre code ici

# %% [markdown]
# **Q1.2 :** Convertissez la colonne 'Date' en type datetime et calculez la somme des ventes par produit.

# %%
# Votre code ici

# %% [markdown]
# <span style='background : salmon' > Note /7</span>

# %% [markdown]
# # Exercice 2 - Visualisation avec Matplotlib et Seaborn (6 points)
#
# **Q2.1 :** Réalisez un graphique en barres représentant les ventes totales par produit.

# %%
# Votre code ici

# %% [markdown]
# <span style='background : salmon' > Note /6</span>

# %% [markdown]
# # Exercice 3 - Programmation Orientée Objet (7 points)
#
# **Q3.1 :** Créez une classe `Article` avec les attributs `nom` et `prix`. Ajoutez une méthode `afficher()`.
# **Q3.2 :** Créez une classe `Electronique` héritant de `Article` avec un attribut `garantie`.

# %%
# Votre code ici

# %% [markdown]
# <span style='background : salmon' > Note /7</span>
